# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from requests.structures import CaseInsensitiveDict
import datetime
from scipy import stats


# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 606

# %%
print(cities[6])
# Out:
# menaka

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
url = "http://api.openweathermap.org/data/2.5/weather"
units = "metric"

# Build partial query URL
query_url = f"{url}?units={units}&appid={weather_api_key}&q="

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0
        
    # Create endpoint URL with each city
    city_url = query_url + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_weather = requests.get(city_url).json()
    
         # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_weather['coord']['lat']
        city_lng = city_weather['coord']['lon']
        city_max_temp = city_weather['main']['temp_max']
        city_humidity = city_weather['main']['humidity']
        city_clouds = city_weather['clouds']['all']
        city_wind = city_weather['wind']['speed']
        city_country = city_weather['sys']['country']
        city_date = city_weather['dt']

        # Append the City information into city_data list
        city_data.append({"City": city, 
                          "Lat": city_lat, 
                          "Lng": city_lng, 
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Date": city_date})

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | isafjordur
# Processing Record 2 of Set 1 | tiksi
# Processing Record 3 of Set 1 | callaway
# Processing Record 4 of Set 1 | faya-largeau
# Processing Record 5 of Set 1 | hermanus
# Processing Record 6 of Set 1 | shiguai
# Processing Record 7 of Set 1 | menaka
# Processing Record 8 of Set 1 | prince rupert
# Processing Record 9 of Set 1 | vilyuchinsk
# Processing Record 10 of Set 1 | port-aux-francais
# Processing Record 11 of Set 1 | tarnogskiy gorodok
# Processing Record 12 of Set 1 | 'ohonua
# City not found. Skipping...
# Processing Record 13 of Set 1 | ocean shores
# Processing Record 14 of Set 1 | chunskiy
# Processing Record 15 of Set 1 | fisterra
# Processing Record 16 of Set 1 | waitangi
# Processing Record 17 of Set 1 | colon
# Processing Record 18 of Set 1 | anadyr
# Processing Record 19 of Set 1 | nova sintra
# Processing Record 20 of Set 1 | pariaman
# Processing Record 21 of Set 1 | longyearbyen
# Processing Record 22 of Set 1 | malango
# Processing Record 23 of Set 1 | iskateley
# Processing Record 24 of Set 1 | flying fish cove
# Processing Record 25 of Set 1 | jamestown
# Processing Record 26 of Set 1 | mebane
# Processing Record 27 of Set 1 | adamstown
# Processing Record 28 of Set 1 | magadan
# Processing Record 29 of Set 1 | grytviken
# Processing Record 30 of Set 1 | puerto natales
# Processing Record 31 of Set 1 | at taj
# Processing Record 32 of Set 1 | thompson
# Processing Record 33 of Set 1 | ahau
# City not found. Skipping...
# Processing Record 34 of Set 1 | gizo
# Processing Record 35 of Set 1 | iqaluit
# Processing Record 36 of Set 1 | west island
# Processing Record 37 of Set 1 | avarua
# Processing Record 38 of Set 1 | al jawf
# Processing Record 39 of Set 1 | taltal
# Processing Record 40 of Set 1 | namdrik
# Processing Record 41 of Set 1 | ushuaia
# Processing Record 42 of Set 1 | tamanrasset
# Processing Record 43 of Set 1 | mpraeso
# Processing Record 44 of Set 1 | sitka
# Processing Record 45 of Set 1 | mount pearl
# Processing Record 46 of Set 1 | college
# Processing Record 47 of Set 1 | stanley
# Processing Record 48 of Set 1 | wladyslawowo
# Processing Record 49 of Set 1 | bilibino
# Processing Record 50 of Set 1 | blackmans bay
# Processing Record 0 of Set 2 | kismayo
# Processing Record 1 of Set 2 | zag
# Processing Record 2 of Set 2 | tughyl
# Processing Record 3 of Set 2 | ujae
# Processing Record 4 of Set 2 | byron bay
# Processing Record 5 of Set 2 | saiha
# Processing Record 6 of Set 2 | tazovsky
# Processing Record 7 of Set 2 | weno
# Processing Record 8 of Set 2 | taiohae
# City not found. Skipping...
# Processing Record 9 of Set 2 | aioun
# Processing Record 10 of Set 2 | keflavik
# Processing Record 11 of Set 2 | lebu
# Processing Record 12 of Set 2 | port alfred
# Processing Record 13 of Set 2 | dudinka
# Processing Record 14 of Set 2 | masterton
# Processing Record 15 of Set 2 | port mathurin
# Processing Record 16 of Set 2 | khovd
# Processing Record 17 of Set 2 | udachny
# Processing Record 18 of Set 2 | yelm
# Processing Record 19 of Set 2 | kuta
# Processing Record 20 of Set 2 | goure
# Processing Record 21 of Set 2 | scottburgh
# Processing Record 22 of Set 2 | paris
# Processing Record 23 of Set 2 | winnemucca
# Processing Record 24 of Set 2 | chinchilla
# Processing Record 25 of Set 2 | margaret river
# Processing Record 26 of Set 2 | bethel
# Processing Record 27 of Set 2 | padang
# Processing Record 28 of Set 2 | kataragama
# City not found. Skipping...
# Processing Record 29 of Set 2 | salinopolis
# Processing Record 30 of Set 2 | bowen
# Processing Record 31 of Set 2 | edinburgh of the seven seas
# Processing Record 32 of Set 2 | ribeira grande
# Processing Record 33 of Set 2 | okha
# Processing Record 34 of Set 2 | namibe
# Processing Record 35 of Set 2 | bandar abbas
# Processing Record 36 of Set 2 | kalevala
# Processing Record 37 of Set 2 | vingt cinq
# City not found. Skipping...
# Processing Record 38 of Set 2 | bardai
# Processing Record 39 of Set 2 | quatre cocos
# Processing Record 40 of Set 2 | yellowknife
# Processing Record 41 of Set 2 | puerto leguizamo
# Processing Record 42 of Set 2 | invercargill
# Processing Record 43 of Set 2 | vorkuta
# Processing Record 44 of Set 2 | grand falls-windsor
# Processing Record 45 of Set 2 | untsukul'
# Processing Record 46 of Set 2 | whitehorse
# Processing Record 47 of Set 2 | mahdia
# Processing Record 48 of Set 2 | egilsstadir
# Processing Record 49 of Set 2 | ocean city
# Processing Record 0 of Set 3 | afaahiti
# Processing Record 1 of Set 3 | queenstown
# Processing Record 2 of Set 3 | tual
# Processing Record 3 of Set 3 | colonia
# Processing Record 4 of Set 3 | antonio enes
# Processing Record 5 of Set 3 | beloyarskiy
# Processing Record 6 of Set 3 | pisco
# Processing Record 7 of Set 3 | santa cruz
# Processing Record 8 of Set 3 | lompoc
# Processing Record 9 of Set 3 | hayma'
# City not found. Skipping...
# Processing Record 10 of Set 3 | choyr
# Processing Record 11 of Set 3 | sur
# Processing Record 12 of Set 3 | san julian
# Processing Record 13 of Set 3 | agva
# City not found. Skipping...
# Processing Record 14 of Set 3 | kayakent
# Processing Record 15 of Set 3 | puerto deseado
# Processing Record 16 of Set 3 | axim
# Processing Record 17 of Set 3 | tazacorte
# Processing Record 18 of Set 3 | hudiksvall
# Processing Record 19 of Set 3 | kodiak
# Processing Record 20 of Set 3 | enewetak
# Processing Record 21 of Set 3 | puerto san carlos
# City not found. Skipping...
# Processing Record 22 of Set 3 | kairouan
# Processing Record 23 of Set 3 | tekeli
# Processing Record 24 of Set 3 | puerto ayora
# Processing Record 25 of Set 3 | vasylivka
# Processing Record 26 of Set 3 | gurupi
# Processing Record 27 of Set 3 | kuloy
# Processing Record 28 of Set 3 | alotau
# City not found. Skipping...
# Processing Record 29 of Set 3 | chonchi
# Processing Record 30 of Set 3 | hasaki
# Processing Record 31 of Set 3 | carqueiranne
# Processing Record 32 of Set 3 | albany
# Processing Record 33 of Set 3 | illizi
# Processing Record 34 of Set 3 | susuman
# Processing Record 35 of Set 3 | alice springs
# Processing Record 36 of Set 3 | tsiombe
# Processing Record 37 of Set 3 | daru
# Processing Record 38 of Set 3 | ruteng
# Processing Record 39 of Set 3 | bredasdorp
# Processing Record 40 of Set 3 | qaqortoq
# Processing Record 41 of Set 3 | arraial do cabo
# Processing Record 42 of Set 3 | antofagasta
# Processing Record 43 of Set 3 | medicine hat
# Processing Record 44 of Set 3 | kavaratti
# Processing Record 45 of Set 3 | berezovo
# Processing Record 46 of Set 3 | vuktyl
# Processing Record 47 of Set 3 | hawaiian paradise park
# Processing Record 48 of Set 3 | utrik
# Processing Record 49 of Set 3 | robertsport
# Processing Record 0 of Set 4 | guatrache
# Processing Record 1 of Set 4 | kushiro
# Processing Record 2 of Set 4 | remire-montjoly
# Processing Record 3 of Set 4 | igarka
# Processing Record 4 of Set 4 | zaozersk
# Processing Record 5 of Set 4 | walcourt
# Processing Record 6 of Set 4 | kavieng
# Processing Record 7 of Set 4 | island harbour
# Processing Record 8 of Set 4 | baruun-urt
# Processing Record 9 of Set 4 | itoman
# Processing Record 10 of Set 4 | mercedes
# Processing Record 11 of Set 4 | naze
# Processing Record 12 of Set 4 | howard springs
# Processing Record 13 of Set 4 | st. john's
# Processing Record 14 of Set 4 | rongelap
# Processing Record 15 of Set 4 | wasagu
# Processing Record 16 of Set 4 | sinabang
# Processing Record 17 of Set 4 | corner brook
# Processing Record 18 of Set 4 | globe
# City not found. Skipping...
# Processing Record 19 of Set 4 | port lincoln
# Processing Record 20 of Set 4 | geraldton
# Processing Record 21 of Set 4 | cherdyn'
# Processing Record 22 of Set 4 | shangzhi
# Processing Record 23 of Set 4 | olonkinbyen
# Processing Record 24 of Set 4 | talnakh
# Processing Record 25 of Set 4 | klyuchi
# Processing Record 26 of Set 4 | alto barinas
# Processing Record 27 of Set 4 | hamilton
# Processing Record 28 of Set 4 | coaticook
# Processing Record 29 of Set 4 | northam
# Processing Record 30 of Set 4 | broome
# Processing Record 31 of Set 4 | la'ie
# Processing Record 32 of Set 4 | sao miguel do araguaia
# Processing Record 33 of Set 4 | linkou
# Processing Record 34 of Set 4 | zheleznogorsk-ilimskiy
# Processing Record 35 of Set 4 | iskushuban
# Processing Record 36 of Set 4 | bouarfa
# Processing Record 37 of Set 4 | georgetown
# Processing Record 38 of Set 4 | zyryanovsk
# Processing Record 39 of Set 4 | elmendorf air force base
# City not found. Skipping...
# Processing Record 40 of Set 4 | kamyshevatskaya
# Processing Record 41 of Set 4 | ulladulla
# Processing Record 42 of Set 4 | carnarvon
# Processing Record 43 of Set 4 | port elizabeth
# Processing Record 44 of Set 4 | chhatak
# Processing Record 45 of Set 4 | mahina
# Processing Record 46 of Set 4 | saipan
# Processing Record 47 of Set 4 | san ignacio de velasco
# Processing Record 48 of Set 4 | arkalyk
# Processing Record 49 of Set 4 | minas de marcona
# Processing Record 0 of Set 5 | ishikari
# Processing Record 1 of Set 5 | hatta
# Processing Record 2 of Set 5 | castillos
# Processing Record 3 of Set 5 | dana point
# Processing Record 4 of Set 5 | kirensk
# Processing Record 5 of Set 5 | extrema
# Processing Record 6 of Set 5 | burley
# Processing Record 7 of Set 5 | korsakov
# Processing Record 8 of Set 5 | punta arenas
# Processing Record 9 of Set 5 | vung tau
# Processing Record 10 of Set 5 | porto novo
# Processing Record 11 of Set 5 | qamdo
# Processing Record 12 of Set 5 | ketchikan
# Processing Record 13 of Set 5 | kill devil hills
# Processing Record 14 of Set 5 | kapuskasing
# Processing Record 15 of Set 5 | acapulco de juarez
# Processing Record 16 of Set 5 | smidovich
# Processing Record 17 of Set 5 | sittwe
# Processing Record 18 of Set 5 | bel ombre
# Processing Record 19 of Set 5 | turuntayevo
# Processing Record 20 of Set 5 | papatowai
# Processing Record 21 of Set 5 | mahanoro
# Processing Record 22 of Set 5 | great falls
# Processing Record 23 of Set 5 | antsiranana
# Processing Record 24 of Set 5 | zakynthos
# Processing Record 25 of Set 5 | tynda
# Processing Record 26 of Set 5 | sanctuary point
# Processing Record 27 of Set 5 | petropavlovsk-kamchatsky
# Processing Record 28 of Set 5 | raiganj
# Processing Record 29 of Set 5 | murun-kuren
# Processing Record 30 of Set 5 | alesund
# Processing Record 31 of Set 5 | palmer
# Processing Record 32 of Set 5 | kuantan
# Processing Record 33 of Set 5 | praia da vitoria
# Processing Record 34 of Set 5 | constitucion
# Processing Record 35 of Set 5 | plettenberg bay
# Processing Record 36 of Set 5 | kidal
# Processing Record 37 of Set 5 | savave village
# City not found. Skipping...
# Processing Record 38 of Set 5 | bulolo
# Processing Record 39 of Set 5 | tofol
# Processing Record 40 of Set 5 | nemuro
# Processing Record 41 of Set 5 | peniche
# Processing Record 42 of Set 5 | ndende
# Processing Record 43 of Set 5 | launceston
# Processing Record 44 of Set 5 | ihosy
# Processing Record 45 of Set 5 | saldanha
# Processing Record 46 of Set 5 | tovarkovskiy
# Processing Record 47 of Set 5 | fortuna
# Processing Record 48 of Set 5 | new norfolk
# Processing Record 49 of Set 5 | marsh harbour
# Processing Record 0 of Set 6 | preobrazheniye
# Processing Record 1 of Set 6 | volchikha
# Processing Record 2 of Set 6 | lorengau
# Processing Record 3 of Set 6 | haiku-pauwela
# Processing Record 4 of Set 6 | darhan
# Processing Record 5 of Set 6 | dunedin
# Processing Record 6 of Set 6 | badger
# Processing Record 7 of Set 6 | muroto-misakicho
# Processing Record 8 of Set 6 | princeville
# Processing Record 9 of Set 6 | touros
# Processing Record 10 of Set 6 | nev'yansk
# Processing Record 11 of Set 6 | wailua homesteads
# Processing Record 12 of Set 6 | yazoo city
# Processing Record 13 of Set 6 | san antonio de pale
# Processing Record 14 of Set 6 | garissa
# Processing Record 15 of Set 6 | pocone
# Processing Record 16 of Set 6 | rio de janeiro
# Processing Record 17 of Set 6 | puerto baquerizo moreno
# Processing Record 18 of Set 6 | stanwood
# Processing Record 19 of Set 6 | holualoa
# Processing Record 20 of Set 6 | bunia
# Processing Record 21 of Set 6 | orapa
# Processing Record 22 of Set 6 | nar'yan-mar
# Processing Record 23 of Set 6 | mirnyy
# Processing Record 24 of Set 6 | mejit
# Processing Record 25 of Set 6 | kagizman
# Processing Record 26 of Set 6 | aasiaat
# Processing Record 27 of Set 6 | sadjoavato
# City not found. Skipping...
# Processing Record 28 of Set 6 | fremantle
# Processing Record 29 of Set 6 | funafuti
# Processing Record 30 of Set 6 | ixtepec
# Processing Record 31 of Set 6 | tchintabaraden
# Processing Record 32 of Set 6 | peruwelz
# Processing Record 33 of Set 6 | brookings
# Processing Record 34 of Set 6 | cadale
# Processing Record 35 of Set 6 | vorgashor
# Processing Record 36 of Set 6 | paphos
# Processing Record 37 of Set 6 | concepcion
# Processing Record 38 of Set 6 | kivioli
# Processing Record 39 of Set 6 | dazhong
# Processing Record 40 of Set 6 | gulf shores
# Processing Record 41 of Set 6 | pago pago
# Processing Record 42 of Set 6 | talara
# Processing Record 43 of Set 6 | altai
# Processing Record 44 of Set 6 | saynshand
# Processing Record 45 of Set 6 | plastun
# Processing Record 46 of Set 6 | huanuni
# Processing Record 47 of Set 6 | bage
# Processing Record 48 of Set 6 | tralee
# Processing Record 49 of Set 6 | nadi
# Processing Record 0 of Set 7 | caleta de carquin
# Processing Record 1 of Set 7 | tolanaro
# Processing Record 2 of Set 7 | abbeville
# Processing Record 3 of Set 7 | kununurra
# Processing Record 4 of Set 7 | caransebes
# Processing Record 5 of Set 7 | al mawsil al jadidah
# Processing Record 6 of Set 7 | trairi
# Processing Record 7 of Set 7 | ust-nera
# Processing Record 8 of Set 7 | isiro
# Processing Record 9 of Set 7 | ola
# Processing Record 10 of Set 7 | keminmaa
# Processing Record 11 of Set 7 | karratha
# Processing Record 12 of Set 7 | south hedland
# Processing Record 13 of Set 7 | quartu sant'elena
# Processing Record 14 of Set 7 | hwange
# Processing Record 15 of Set 7 | sao vicente
# Processing Record 16 of Set 7 | kulykivka
# Processing Record 17 of Set 7 | forster
# Processing Record 18 of Set 7 | kuragino
# Processing Record 19 of Set 7 | waterloo
# Processing Record 20 of Set 7 | usinsk
# Processing Record 21 of Set 7 | cockburn town
# Processing Record 22 of Set 7 | alofi
# Processing Record 23 of Set 7 | betio village
# Processing Record 24 of Set 7 | miyako
# Processing Record 25 of Set 7 | yanykurgan
# Processing Record 26 of Set 7 | thinadhoo
# Processing Record 27 of Set 7 | belmonte
# Processing Record 28 of Set 7 | mawlamyinegyunn
# Processing Record 29 of Set 7 | lazaro cardenas
# Processing Record 30 of Set 7 | bogale
# Processing Record 31 of Set 7 | papao
# Processing Record 32 of Set 7 | yangor
# City not found. Skipping...
# Processing Record 33 of Set 7 | cole harbour
# Processing Record 34 of Set 7 | pervomayskiy
# Processing Record 35 of Set 7 | ambovombe
# Processing Record 36 of Set 7 | ancud
# Processing Record 37 of Set 7 | east london
# Processing Record 38 of Set 7 | cidreira
# Processing Record 39 of Set 7 | opuwo
# Processing Record 40 of Set 7 | ushtobe
# Processing Record 41 of Set 7 | atafu village
# Processing Record 42 of Set 7 | gwaram
# Processing Record 43 of Set 7 | borger
# Processing Record 44 of Set 7 | flin flon
# Processing Record 45 of Set 7 | troitskoye
# Processing Record 46 of Set 7 | apia
# Processing Record 47 of Set 7 | porbandar
# Processing Record 48 of Set 7 | usogorsk
# Processing Record 49 of Set 7 | bonthe
# Processing Record 0 of Set 8 | nizhniy odes
# Processing Record 1 of Set 8 | kristiansund
# Processing Record 2 of Set 8 | nuuk
# Processing Record 3 of Set 8 | belabo
# Processing Record 4 of Set 8 | lukolela
# Processing Record 5 of Set 8 | sassnitz
# Processing Record 6 of Set 8 | murzuq
# Processing Record 7 of Set 8 | long beach
# Processing Record 8 of Set 8 | keren
# Processing Record 9 of Set 8 | villablino
# Processing Record 10 of Set 8 | cabo san lucas
# Processing Record 11 of Set 8 | kaitong
# Processing Record 12 of Set 8 | cheremukhovo
# Processing Record 13 of Set 8 | yuzhno-kurilsk
# Processing Record 14 of Set 8 | poxoreo
# Processing Record 15 of Set 8 | guarapari
# Processing Record 16 of Set 8 | vilyuysk
# Processing Record 17 of Set 8 | katsuura
# Processing Record 18 of Set 8 | quibdo
# Processing Record 19 of Set 8 | kulia village
# City not found. Skipping...
# Processing Record 20 of Set 8 | san patricio
# Processing Record 21 of Set 8 | coquimbo
# Processing Record 22 of Set 8 | wickenburg
# Processing Record 23 of Set 8 | ilulissat
# Processing Record 24 of Set 8 | kingston
# Processing Record 25 of Set 8 | hotan
# Processing Record 26 of Set 8 | tucuma
# Processing Record 27 of Set 8 | tranovaho
# City not found. Skipping...
# Processing Record 28 of Set 8 | nova olimpia
# Processing Record 29 of Set 8 | juva
# Processing Record 30 of Set 8 | qarazhal
# Processing Record 31 of Set 8 | la ronge
# Processing Record 32 of Set 8 | griffith
# Processing Record 33 of Set 8 | floro
# Processing Record 34 of Set 8 | santarem
# Processing Record 35 of Set 8 | newman
# Processing Record 36 of Set 8 | vadso
# Processing Record 37 of Set 8 | bacacay
# Processing Record 38 of Set 8 | mount isa
# Processing Record 39 of Set 8 | hammerfest
# Processing Record 40 of Set 8 | guerrero negro
# Processing Record 41 of Set 8 | jayapura
# Processing Record 42 of Set 8 | neftegorsk
# Processing Record 43 of Set 8 | antigonish
# Processing Record 44 of Set 8 | tshabong
# Processing Record 45 of Set 8 | guymon
# Processing Record 46 of Set 8 | lerwick
# Processing Record 47 of Set 8 | arroyo
# Processing Record 48 of Set 8 | cavalaire-sur-mer
# Processing Record 49 of Set 8 | vila velha
# Processing Record 0 of Set 9 | voitsberg
# Processing Record 1 of Set 9 | dispur
# Processing Record 2 of Set 9 | luau
# Processing Record 3 of Set 9 | katima mulilo
# Processing Record 4 of Set 9 | rikaze
# Processing Record 5 of Set 9 | peace river
# Processing Record 6 of Set 9 | fuvahmulah
# City not found. Skipping...
# Processing Record 7 of Set 9 | codrington
# Processing Record 8 of Set 9 | hilo
# Processing Record 9 of Set 9 | qui nhon
# Processing Record 10 of Set 9 | luganville
# Processing Record 11 of Set 9 | buxerolles
# Processing Record 12 of Set 9 | williams lake
# Processing Record 13 of Set 9 | makurazaki
# Processing Record 14 of Set 9 | ta`u
# Processing Record 15 of Set 9 | cardenas
# Processing Record 16 of Set 9 | awjilah
# Processing Record 17 of Set 9 | cananeia
# Processing Record 18 of Set 9 | terrace
# Processing Record 19 of Set 9 | nianzishan
# Processing Record 20 of Set 9 | new plymouth
# Processing Record 21 of Set 9 | saint-paul
# Processing Record 22 of Set 9 | aswan
# Processing Record 23 of Set 9 | fort st. john
# Processing Record 24 of Set 9 | arangaon
# Processing Record 25 of Set 9 | waingapu
# Processing Record 26 of Set 9 | envira
# Processing Record 27 of Set 9 | arcadia
# Processing Record 28 of Set 9 | mossendjo
# Processing Record 29 of Set 9 | devinuwara
# City not found. Skipping...
# Processing Record 30 of Set 9 | guiglo
# Processing Record 31 of Set 9 | yambio
# Processing Record 32 of Set 9 | hillsborough
# Processing Record 33 of Set 9 | parksville
# Processing Record 34 of Set 9 | kerikeri
# Processing Record 35 of Set 9 | palikir - national government center
# Processing Record 36 of Set 9 | santa maria del oro
# Processing Record 37 of Set 9 | lamu
# Processing Record 38 of Set 9 | mersa matruh
# Processing Record 39 of Set 9 | nyurba
# Processing Record 40 of Set 9 | iowa park
# Processing Record 41 of Set 9 | tando bago
# Processing Record 42 of Set 9 | rugaji
# Processing Record 43 of Set 9 | sen monorom
# Processing Record 44 of Set 9 | khash
# Processing Record 45 of Set 9 | zhezqazghan
# Processing Record 46 of Set 9 | raja
# Processing Record 47 of Set 9 | lalin
# Processing Record 48 of Set 9 | prince albert
# Processing Record 49 of Set 9 | tokar
# Processing Record 0 of Set 10 | balabac
# Processing Record 1 of Set 10 | ghat
# Processing Record 2 of Set 10 | saint croix
# Processing Record 3 of Set 10 | kargasok
# Processing Record 4 of Set 10 | santa terezinha
# Processing Record 5 of Set 10 | kalmunai
# Processing Record 6 of Set 10 | crane
# Processing Record 7 of Set 10 | tahe
# Processing Record 8 of Set 10 | dubinino
# Processing Record 9 of Set 10 | nova vicosa
# Processing Record 10 of Set 10 | gornyatskiy
# Processing Record 11 of Set 10 | tlacotepec
# Processing Record 12 of Set 10 | tommot
# Processing Record 13 of Set 10 | swakopmund
# Processing Record 14 of Set 10 | bougouni
# Processing Record 15 of Set 10 | piedmont
# Processing Record 16 of Set 10 | orzysz
# Processing Record 17 of Set 10 | tweed heads
# Processing Record 18 of Set 10 | gwanda
# Processing Record 19 of Set 10 | portland
# Processing Record 20 of Set 10 | kem'
# Processing Record 21 of Set 10 | kaka
# Processing Record 22 of Set 10 | eenhana
# Processing Record 23 of Set 10 | tutoia
# Processing Record 24 of Set 10 | saratamata
# City not found. Skipping...
# Processing Record 25 of Set 10 | nkowakowa
# Processing Record 26 of Set 10 | cabanas
# Processing Record 27 of Set 10 | marquette
# Processing Record 28 of Set 10 | chilecito
# Processing Record 29 of Set 10 | zaltan
# Processing Record 30 of Set 10 | bokani
# Processing Record 31 of Set 10 | luderitz
# Processing Record 32 of Set 10 | conde
# Processing Record 33 of Set 10 | serafimovich
# Processing Record 34 of Set 10 | labrador city
# Processing Record 35 of Set 10 | manp'o
# City not found. Skipping...
# Processing Record 36 of Set 10 | plouzane
# Processing Record 37 of Set 10 | saint-pierre
# Processing Record 38 of Set 10 | samalut
# Processing Record 39 of Set 10 | nilsia
# Processing Record 40 of Set 10 | pacasmayo
# Processing Record 41 of Set 10 | mata-utu
# Processing Record 42 of Set 10 | corbelia
# Processing Record 43 of Set 10 | sisimiut
# Processing Record 44 of Set 10 | sankt johann in tirol
# Processing Record 45 of Set 10 | kruisfontein
# Processing Record 46 of Set 10 | vila franca do campo
# Processing Record 47 of Set 10 | saudarkrokur
# Processing Record 48 of Set 10 | happy valley-goose bay
# Processing Record 49 of Set 10 | sorong
# Processing Record 0 of Set 11 | prattville
# Processing Record 1 of Set 11 | kourou
# Processing Record 2 of Set 11 | jalai nur
# Processing Record 3 of Set 11 | uturoa
# Processing Record 4 of Set 11 | salaqi
# Processing Record 5 of Set 11 | rundu
# Processing Record 6 of Set 11 | port hedland
# Processing Record 7 of Set 11 | ust'-ordynskiy
# Processing Record 8 of Set 11 | orting
# Processing Record 9 of Set 11 | ad-damazin
# Processing Record 10 of Set 11 | bakchar
# Processing Record 11 of Set 11 | nikolayevsk-on-amure
# Processing Record 12 of Set 11 | north elba
# Processing Record 13 of Set 11 | pacific grove
# Processing Record 14 of Set 11 | bamboo flat
# Processing Record 15 of Set 11 | zabid
# Processing Record 16 of Set 11 | kokoda
# Processing Record 17 of Set 11 | smithers
# Processing Record 18 of Set 11 | pembroke
# Processing Record 19 of Set 11 | auki
# Processing Record 20 of Set 11 | dhidhdhoo
# Processing Record 21 of Set 11 | gunjur
# Processing Record 22 of Set 11 | novyy urgal
# Processing Record 23 of Set 11 | olgii
# City not found. Skipping...
# Processing Record 24 of Set 11 | bridgewater
# Processing Record 25 of Set 11 | nuku'alofa
# Processing Record 26 of Set 11 | kamloops
# Processing Record 27 of Set 11 | vernon
# Processing Record 28 of Set 11 | zuni pueblo
# Processing Record 29 of Set 11 | hadibu
# Processing Record 30 of Set 11 | chernyshevsk
# Processing Record 31 of Set 11 | freetown
# Processing Record 32 of Set 11 | sainte-marie
# Processing Record 33 of Set 11 | saint-francois
# Processing Record 34 of Set 11 | sabang
# Processing Record 35 of Set 11 | badiyah
# Processing Record 36 of Set 11 | taco pozo
# Processing Record 37 of Set 11 | chegdomyn
# Processing Record 38 of Set 11 | andergrove
# Processing Record 39 of Set 11 | deqing
# Processing Record 40 of Set 11 | anibare
# City not found. Skipping...
# Processing Record 41 of Set 11 | sabha
# Processing Record 42 of Set 11 | talcahuano
# Processing Record 43 of Set 11 | hachinohe
# Processing Record 44 of Set 11 | akjoujt
# Processing Record 45 of Set 11 | skovorodino
# Processing Record 46 of Set 11 | anda
# Processing Record 47 of Set 11 | mahajanga
# Processing Record 48 of Set 11 | xuanzhou
# Processing Record 49 of Set 11 | borba
# Processing Record 0 of Set 12 | port augusta
# Processing Record 1 of Set 12 | el alto
# Processing Record 2 of Set 12 | dwarka
# Processing Record 3 of Set 12 | san rafael del sur
# Processing Record 4 of Set 12 | despenaderos
# Processing Record 5 of Set 12 | mahibadhoo
# Processing Record 6 of Set 12 | atakpame
# Processing Record 7 of Set 12 | derzhavinsk
# Processing Record 8 of Set 12 | mogocha
# Processing Record 9 of Set 12 | danilovka
# Processing Record 10 of Set 12 | deqen
# Processing Record 11 of Set 12 | huanggang
# Processing Record 12 of Set 12 | calvi
# Processing Record 13 of Set 12 | pandan
# Processing Record 14 of Set 12 | bankura
# Processing Record 15 of Set 12 | shixing
# Processing Record 16 of Set 12 | qarqaraly
# Processing Record 17 of Set 12 | polyarnyy
# Processing Record 18 of Set 12 | kloulklubed
# Processing Record 19 of Set 12 | devils lake
# Processing Record 20 of Set 12 | teknaf
# Processing Record 21 of Set 12 | buriti alegre
# Processing Record 22 of Set 12 | beacon square
# Processing Record 23 of Set 12 | ermoupolis
# Processing Record 24 of Set 12 | saint-philippe
# Processing Record 25 of Set 12 | san juan
# Processing Record 26 of Set 12 | ardakan
# Processing Record 27 of Set 12 | cerro largo
# Processing Record 28 of Set 12 | juneau
# Processing Record 29 of Set 12 | kota kinabalu
# Processing Record 30 of Set 12 | as sulayyil
# Processing Record 31 of Set 12 | agadez
# Processing Record 32 of Set 12 | lufilufi
# Processing Record 33 of Set 12 | manta
# Processing Record 34 of Set 12 | sofifi
# City not found. Skipping...
# Processing Record 35 of Set 12 | tionk essil
# Processing Record 36 of Set 12 | horta
# Processing Record 37 of Set 12 | terebovlya
# Processing Record 38 of Set 12 | celestun
# Processing Record 39 of Set 12 | toga village
# City not found. Skipping...
# Processing Record 40 of Set 12 | road town
# Processing Record 41 of Set 12 | mhangura
# Processing Record 42 of Set 12 | pahrump
# Processing Record 43 of Set 12 | pierre
# Processing Record 44 of Set 12 | ilza
# Processing Record 45 of Set 12 | severo-yeniseyskiy
# Processing Record 46 of Set 12 | ngorongoro
# Processing Record 47 of Set 12 | aiquile
# Processing Record 48 of Set 12 | achinsk
# Processing Record 49 of Set 12 | gadzhiyevo
# Processing Record 0 of Set 13 | lepsy
# Processing Record 1 of Set 13 | bikenibeu village
# Processing Record 2 of Set 13 | cheney
# Processing Record 3 of Set 13 | myanaung
# Processing Record 4 of Set 13 | borzya
# Processing Record 5 of Set 13 | richards bay
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          582
# Lat           582
# Lng           582
# Max Temp      582
# Humidity      582
# Cloudiness    582
# Wind Speed    582
# Country       582
# Date          582
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0    isafjordur  66.0755  -23.1240     -0.09        91         100
# 1         tiksi  71.6872  128.8694    -25.05        99          42
# 2      callaway  30.1530  -85.5699     19.45        80           0
# 3  faya-largeau  17.9257   19.1043     23.96        18           0
# 4      hermanus -34.4187   19.2345     15.84        84         100
#
#    Wind Speed Country        Date
# 0       11.47      IS  1699234390
# 1        2.29      RU  1699234390
# 2        2.06      US  1699234390
# 3        6.72      TD  1699234391
# 4        1.50      ZA  1699234391

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          isafjordur  66.0755  -23.1240     -0.09        91         100
# 1               tiksi  71.6872  128.8694    -25.05        99          42
# 2            callaway  30.1530  -85.5699     19.45        80           0
# 3        faya-largeau  17.9257   19.1043     23.96        18           0
# 4            hermanus -34.4187   19.2345     15.84        84         100
#
#          Wind Speed Country        Date
# City_ID
# 0             11.47      IS  1699234390
# 1              2.29      RU  1699234390
# 2              2.06      US  1699234390
# 3              6.72      TD  1699234391
# 4              1.50      ZA  1699234391

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature

#convert date time for chart titles
top_date = pd.to_datetime(city_data_df.iloc[0, 8], unit='s').strftime("%Y-%m-%d")

plt.title(f"City Max Latitude vs. Temperature {top_date}")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (c)")
plt.grid(True, linestyle='-', alpha=1)
plt.scatter(city_data_df['Lat'], city_data_df['Max Temp'], marker="o", color="steelblue", edgecolors="black")
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
plt.title(f"City Max Latitude vs. Humidity {top_date}")
plt.xlabel("Latitude")
plt.ylabel("Humidity (%)")
plt.grid(True, linestyle='-', alpha=1)
plt.scatter(city_data_df['Lat'], city_data_df['Humidity'], marker="o", color="steelblue", edgecolors="black")
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
plt.title(f"City Max Latitude vs. Cloudiness {top_date}")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness (%)")
plt.grid(True, linestyle='-', alpha=1)
plt.scatter(city_data_df['Lat'], city_data_df['Cloudiness'], marker="o", color="steelblue", edgecolors="black")
plt.show()

# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
plt.title(f"City Max Latitude vs. Wind Speed {top_date}")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed (m/s)")
plt.grid(True, linestyle='-', alpha=1)
plt.scatter(city_data_df['Lat'], city_data_df['Wind Speed'], marker="o", color="steelblue", edgecolors="black")
plt.show()
# Incorporate the other graph properties
# YOUR CODE HERE

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots
#Trying to figure out how to pass on the labels was tricky, found some info on stack overflow about passing multiple arguments https://stackoverflow.com/questions/50117875/python-graph-function-that-takes-multiple-optional-arguments

def lrp_function(x_values, y_values, x_label, y_label, ann_pos):

    (slope, intercept, rvalue, pvalue, stderr) = linregress(x_values, y_values)
    regress_values = x_values * slope + intercept
    line_eq = "y = " + str(round(slope,2)) + "x + " + str(round(intercept,2))
    plt.scatter(x_values,y_values)
    plt.plot(x_values,regress_values,"r-")
    plt.annotate(line_eq,ann_pos,fontsize=15,color="red")
    plt.xlabel(x_label)
    plt.ylabel(y_label)
    print(f"The r-squared is: {rvalue**2}")
    plt.show()

# %%
city_data_df.head(1)
# Out:
#                City      Lat     Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        isafjordur  66.0755 -23.124     -0.09        91         100
#
#          Wind Speed Country        Date
# City_ID
# 0             11.47      IS  1699234390

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df[city_data_df['Lat'] >= 0]

# Display sample data
northern_hemi_df.head()
# Out:
#                  City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0          isafjordur  66.0755  -23.1240     -0.09        91         100
# 1               tiksi  71.6872  128.8694    -25.05        99          42
# 2            callaway  30.1530  -85.5699     19.45        80           0
# 3        faya-largeau  17.9257   19.1043     23.96        18           0
# 5             shiguai  40.7058  110.2856     -5.35        48           2
#
#          Wind Speed Country        Date
# City_ID
# 0             11.47      IS  1699234390
# 1              2.29      RU  1699234390
# 2              2.06      US  1699234390
# 3              6.72      TD  1699234391
# 5              4.77      CN  1699234391

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df[city_data_df['Lat'] < 0]

# Display sample data
southern_hemi_df.head()
# Out:
#                       City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 4                 hermanus -34.4187   19.2345     15.84        84         100
# 9        port-aux-francais -49.3500   70.2167      3.06        76         100
# 14                waitangi -43.9535 -176.5597     13.23        83         100
# 18                pariaman  -0.6190  100.1200     26.03        79          22
# 20                 malango  -2.9627  119.9001     28.27        52          55
#
#          Wind Speed Country        Date
# City_ID
# 4              1.50      ZA  1699234391
# 9             14.33      TF  1699234034
# 14             3.13      NZ  1699234394
# 18             0.47      ID  1699234369
# 20             1.77      ID  1699234396

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Max Temp']

x_label = 'Latitude'
y_label = 'Max Temp'
x_range = (-5,85)
y_range = (-25,45)
ann_pos = (5,-15)
lrp_function(x_values, y_values, x_label, y_label, ann_pos)
# Out:
# The r-squared is: 0.7262449279156608

# %%
# Linear regression on Southern Hemisphere
# Linear regression on Northern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Max Temp']

x_label = 'Latitude'
y_label = 'Max Temp'
x_range = (-60,0)
y_range = (0,50)
ann_pos = (-55,35)
lrp_function(x_values, y_values, x_label, y_label, ann_pos)
# Out:
# The r-squared is: 0.4159067872462009

# %% [markdown]
# **Discussion about the linear relationship:** Comparing latitude and max temps for the Northern Hemisphere, there is a negative relationship, meaning as latitude increases there is a decrease in temps with a R-Squared is 0.72. For the Southern Hemisphere, there is a positive relationship, meaning that as latitude increases there is an increase in temps, though in this case the R-Squared is only 0.41 so the relationship is not as strong as in the Northern Hemisphere.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
northern_hemi_df.head(1)
# Out:
#                City      Lat     Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0        isafjordur  66.0755 -23.124     -0.09        91         100
#
#          Wind Speed Country        Date
# City_ID
# 0             11.47      IS  1699234390

# %%
# Northern Hemisphere
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Humidity']

x_label = 'Latitude'
y_label = 'Humidity'
x_range = (-5,85)
y_range = (0,105)
ann_pos = (40,10)
lrp_function(x_values, y_values, x_label, y_label, ann_pos)
# Out:
# The r-squared is: 0.07480145178070371

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Humidity']

x_label = 'Latitude'
y_label = 'Humidity'
x_range = (-60,5)
y_range = (0,105)
ann_pos = (-50,20)
lrp_function(x_values, y_values, x_label, y_label, ann_pos)
# Out:
# The r-squared is: 0.035051186725081965

# %% [markdown]
# **Discussion about the linear relationship:** Both in the Northern and Southern Hemispheres there is a positive relationship between latitude and humidity, but these relationships are not strong. In the North the r-squared is 0.07 and in the South it's 0.03. Other factors must contribute to humidity more than latitude.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Cloudiness']

x_label = 'Latitude'
y_label = 'Cloudiness'
x_range = (-5,85)
y_range = (-5,105)
ann_pos = (40,10)
lrp_function(x_values, y_values, x_label, y_label, ann_pos)
# Out:
# The r-squared is: 0.060262346596748964

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Cloudiness']

x_label = 'Latitude'
y_label = 'Cloudiness'
x_range = (-60,5)
y_range = (-5,105)
ann_pos = (-30,30)
lrp_function(x_values, y_values, x_label, y_label, ann_pos)
# Out:
# The r-squared is: 0.018755789920167427

# %% [markdown]
# **Discussion about the linear relationship:** Once again, both in the Northern and Southern Hemispheres there is a positive relationship between latitude and cloudiness, but these relationships are not strong. In the North the r-squared is 0.06 and in the South it's 0.01. Other factors must contribute to cloudiness more than latitude.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df['Lat']
y_values = northern_hemi_df['Wind Speed']

x_label = 'Latitude'
y_label = 'Wind Speed'
x_range = (-5,85)
y_range = (-5,16)
ann_pos = (10,12)
lrp_function(x_values, y_values, x_label, y_label, ann_pos)
# Out:
# The r-squared is: 0.04949693133507094

# %%
# Southern Hemisphere
x_values = southern_hemi_df['Lat']
y_values = southern_hemi_df['Wind Speed']

x_label = 'Latitude'
y_label = 'Wind Speed'
x_range = (-60,5)
y_range = (-5,16)
ann_pos = (-50,12)
lrp_function(x_values, y_values, x_label, y_label, ann_pos)
# Out:
# The r-squared is: 0.015475970028523177

# %% [markdown]
# **Discussion about the linear relationship:** In this case in the north there appears to be a weak positive relationship at r-squared 0.04 and in the south a weak negative relationship at 0.01. Latitude does not appear to be a primary driver of wind speeds.
